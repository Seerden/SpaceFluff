# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# load classifications
df = pd.read_csv('./zooniverse_exports/classify-hardcore-edition-classifications.csv', delimiter=",")

# %%
df.head()
# Out:
#    classification_id                           user_name  user_id  \
# 0          229608794  not-logged-in-2f4f5d73a0d88e03a7d4      NaN
# 1          229609090  not-logged-in-2f4f5d73a0d88e03a7d4      NaN
# 2          229609110  not-logged-in-2f4f5d73a0d88e03a7d4      NaN
# 3          229609146  not-logged-in-2f4f5d73a0d88e03a7d4      NaN
# 4          229609156  not-logged-in-2f4f5d73a0d88e03a7d4      NaN
#
#                 user_ip  workflow_id               workflow_name  \
# 0  2f4f5d73a0d88e03a7d4        14226  Classify! Hardcore edition
# 1  2f4f5d73a0d88e03a7d4        14226  Classify! Hardcore edition
# 2  2f4f5d73a0d88e03a7d4        14226  Classify! Hardcore edition
# 3  2f4f5d73a0d88e03a7d4        14226  Classify! Hardcore edition
# 4  2f4f5d73a0d88e03a7d4        14226  Classify! Hardcore edition
#
#    workflow_version               created_at  gold_standard  expert  \
# 0            76.125  2020-04-25 13:04:39 UTC            NaN     NaN
# ...

# %%
df['subject_data'] = df['subject_data'].apply(json.loads)
df['annotations'] = df['annotations'].apply(json.loads)

# %%
df['annotations'].loc[1]
# Out:
# [{'task': 'T0',
#   'task_label': 'Look at the very center of the image: do you see a single galaxy or a cluster of objects?',
#   'value': 'Galaxy'},
#  {'task': 'T1',
#   'task_label': 'What color is the galaxy?',
#   'value': 'Red/yellow'},
#  {'task': 'T2',
#   'task_label': 'Is the galaxy fluffy or is it bright?',
#   'value': 'Fluffy'},
#  {'task': 'T3',
#   'task_label': 'Does the galaxy have a visible core?',
#   'value': 'No'},
#  {'task': 'T4', 'task_label': 'What shape is the galaxy?', 'value': 'Round'},
#  {'task': 'T5',
#   'task_label': 'How would you describe the texture of the galaxy?',
#   'value': 'Diffuse and transparent'},
#  {'task': 'T8',
#   'task_label': 'Does it look like the galaxy has a companion?',
#   'value': 'No'}]
