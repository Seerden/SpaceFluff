# %% [markdown]
# # Goal:
#
# Inspect an image from a Space Fluff object, downloaded from the Zooniverse website.

# %%
from PIL import Image
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
image_filenames = os.listdir('./thumbnails')

# %%
image = image_filenames[0]

# %%
with Image.open('./thumbnails/{}'.format(image)) as im:
    plt.imshow(np.asarray(im))
